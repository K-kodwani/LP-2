# %%
#SELECTION SORT
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
        print(f"Step {i+1}: {arr} | Heuristic (min value): {arr[0]}")  # Display heuristic

    return arr

# Taking user input
arr = list(map(int, input("Enter numbers to sort (space-separated): ").split()))
sorted_arr = selection_sort(arr)
print("Sorted Array:", sorted_arr)
print('Name:Hitesh Pal\nRoll no:22132')
# Out:
# Enter numbers to sort (space-separated):  1 4 6 9 8 5 6
# Step 1: [1, 4, 6, 9, 8, 5, 6] | Heuristic (min value): 1
# Step 2: [1, 4, 6, 9, 8, 5, 6] | Heuristic (min value): 1
# Step 3: [1, 4, 5, 9, 8, 6, 6] | Heuristic (min value): 1
# Step 4: [1, 4, 5, 6, 8, 9, 6] | Heuristic (min value): 1
# Step 5: [1, 4, 5, 6, 6, 9, 8] | Heuristic (min value): 1
# Step 6: [1, 4, 5, 6, 6, 8, 9] | Heuristic (min value): 1
# Step 7: [1, 4, 5, 6, 6, 8, 9] | Heuristic (min value): 1
# Sorted Array: [1, 4, 5, 6, 6, 8, 9]
# Name:Hitesh Pal
# Roll no:22132

# %%
#MST
import heapq

def prim_mst(graph, start):
    mst = []
    visited = set()
    min_heap = [(0, start, None)]  # (cost, node, parent)
    
    while min_heap:
        cost, node, parent = heapq.heappop(min_heap)
        if node not in visited:
            visited.add(node)
            if parent is not None:
                mst.append((parent, node, cost))
                print(f"Adding edge {parent} -> {node} with cost {cost} | Heuristic: {cost}")  # Heuristic

            for neighbor, weight in graph[node]:
                if neighbor not in visited:
                    heapq.heappush(min_heap, (weight, neighbor, node))
    
    return mst

# Taking user input
graph = {}
num_edges = int(input("Enter number of edges: "))
print("Enter edges in the format 'node1 node2 weight':")
for _ in range(num_edges):
    u, v, w = input().split()
    w = int(w)
    graph.setdefault(u, []).append((v, w))
    graph.setdefault(v, []).append((u, w))

start_node = input("Enter the start node: ")
mst_result = prim_mst(graph, start_node)
print("Minimum Spanning Tree:", mst_result)
print('Name:Hitesh Pal\nRoll no:22132')
# Out:
# Enter number of edges:  4
# Enter edges in the format 'node1 node2 weight':
#  A B 2
#   A C 3
#  B C 1
#  B D 2
# Enter the start node:  A
# Adding edge A -> B with cost 2 | Heuristic: 2
# Adding edge B -> C with cost 1 | Heuristic: 1
# Adding edge B -> D with cost 2 | Heuristic: 2
# Minimum Spanning Tree: [('A', 'B', 2), ('B', 'C', 1), ('B', 'D', 2)]
# Name:Hitesh Pal
# Roll no:22132
